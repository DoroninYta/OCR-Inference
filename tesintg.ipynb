# %%
from ultralytics import YOLO #
import torch
import cv2 as cv 
import numpy as np
from pathlib import Path

# %%
folder = Path("/home/user/3_numbers/ocr_show_work/video")
(folder / "3.mp4").with_suffix(".avi")
# Out:
# PosixPath('/home/user/3_numbers/ocr_show_work/video/3.avi')

# %%
model = YOLO("yolov8x.pt")
result = model(folder / "7.avi", save=True, stream=false)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/6000) /home/user/3_numbers/ocr_show_work/video/7.avi: 384x640 1 person, 12 cars, 1 truck, 1 traffic light, 1 stop sign, 29.5ms
# video 1/1 (frame 2/6000) /home/user/3_numbers/ocr_show_work/video/7.avi: 384x640 3 persons, 13 cars, 1 truck, 1 traffic light, 1 stop sign, 19.6ms
# ...
